# %%
#Importing all The Libraries
import pandas as pd
import numpy as np
from keras.models import Sequential
from keras.layers import Dense
from sklearn.model_selection import train_test_split
# Out:
# Using TensorFlow backend.

# %%
#importing our DataSet
#Benign -Safe
#Malignant-Harmful
dataframe = pd.read_csv("breastcancer.csv")

# %%
#printing first 10 Datasets 
dataframe.head(10)
# Out:
#    clump_thickness  uniform_cell_size  uniform_cell_shape  marginal_adhesion  \
# 0                5                  1                   1                  1
# 1                5                  4                   4                  5
# 2                3                  1                   1                  1
# 3                6                  8                   8                  1
# 4                4                  1                   1                  3
# 5                8                 10                  10                  8
# 6                1                  1                   1                  1
# 7                2                  1                   2                  1
# 8                2                  1                   1                  1
# 9                4                  2                   1                  1
#
#    single_epi_cell_size bare_nuclei  bland_chromation  normal_nucleoli  \
# ...

# %%
#Learning About Feature Selection and removing Values which are not Required
dataframe = dataframe.drop('id', 1)
df_label = dataframe['class']
df_features = dataframe.drop('class', 1)
df_features.replace('?', -99999, inplace=True)

print(df_label.head())
df_features.head()
# Out:
# 0    2
# 1    2
# 2    2
# 3    2
# 4    2
# Name: class, dtype: int64
#    clump_thickness  uniform_cell_size  uniform_cell_shape  marginal_adhesion  \
# 0                5                  1                   1                  1
# 1                5                  4                   4                  5
# 2                3                  1                   1                  1
# 3                6                  8                   8                  1
# 4                4                  1                   1                  3
#
#    single_epi_cell_size bare_nuclei  bland_chromation  normal_nucleoli  \
# 0                     2           1                 3                1
# 1                     7          10                 3                2
# 2                     2           2                 3                1
# 3                     3           4                 3                7
# 4                     2           1                 3                1
#
# ...

# %%
label = []
for lab in df_label:
    if lab == 2:
        label.append([1, 0])  # class 2
    elif lab == 4:
        label.append([0, 1])  # class 4

# %%
data = np.array(df_features)
label = np.array(label)
print(data.shape,label.shape)
# Out:
# (699, 9) (699, 2)

# %%
x_train, x_test, y_train, y_test = train_test_split(data, label, test_size=0.2, random_state=42)
x_train.shape
# Out:
# (559, 9)

# %%
model = Sequential()
model.add(Dense(500, input_dim=9, activation='sigmoid'))
model.add(Dense(100, activation='tanh'))
model.add(Dense(2, activation='softmax'))
model.compile(loss='mean_squared_error', optimizer='adam', metrics=['accuracy'])
model.fit(data, label, epochs=1000, batch_size=70, validation_data=(x_test, y_test))
# Out:
# Train on 699 samples, validate on 140 samples
# Epoch 1/1000
# 699/699 [==============================] - 0s 317us/step - loss: 0.0803 - acc: 0.9185 - val_loss: 0.0271 - val_acc: 0.9643
# Epoch 2/1000
# 699/699 [==============================] - 0s 59us/step - loss: 0.0298 - acc: 0.9642 - val_loss: 0.0213 - val_acc: 0.9786
# Epoch 3/1000
# 699/699 [==============================] - 0s 40us/step - loss: 0.0252 - acc: 0.9628 - val_loss: 0.0196 - val_acc: 0.9786
# Epoch 4/1000
# 699/699 [==============================] - 0s 43us/step - loss: 0.0240 - acc: 0.9728 - val_loss: 0.0197 - val_acc: 0.9714
# Epoch 5/1000
# 699/699 [==============================] - 0s 44us/step - loss: 0.0236 - acc: 0.9728 - val_loss: 0.0178 - val_acc: 0.9786
# Epoch 6/1000
# 699/699 [==============================] - 0s 47us/step - loss: 0.0241 - acc: 0.9714 - val_loss: 0.0173 - val_acc: 0.9786
# Epoch 7/1000
# ...

# %%
feature_try = np.array([[5,1,1,1,2,1,3,1,1]])
feature_try2 = np.array([[3,1,1,1,2,3,3,1,1]])
feature_try3 = np.array([[6,8,8,1,3,4,3,7,1]])
feature_try4 = np.array([[8,10,10,8,7,10,9,7,1]])


result =model.predict_classes(feature_try4)

# %%
if result==0:
    print("Benign")
else:
    print("Malignant")
# Out:
# Malignant
